# %%
nums = [100, 200, 300, 400, 500]
nums.pop()
nums.pop()
print(nums)
# Out:
# [100, 200, 300]

# %%
nums = [1,2,3,4,5]
nums.remove(4)
nums.remove(5)
print(nums)
# Out:
# [1, 2, 3]

# %%
nums = [1,2,3,4,5]
num = nums[0:3]
print(num)
# Out:
# [1, 2, 3]

# %%
nums = [100, 200, 300, 400, 500]
del nums[3]
del nums[3]
print(nums)
# Out:
# [100, 200, 300]

# %%
l = [200, 100, 300]
l.insert(2,10000)
print(l)
# Out:
# [200, 100, 10000, 300]

# %%
l = [100, 200, 300]
print(type(1))
# Out:
# <class 'int'>

# %%
a = 2.22
print(type(a))
# Out:
# <class 'float'>

# %%
a = 1
print(a)
# Out:
# 1

# %%
a = 10
b = 2
for i in range(1,5,2):
  a += i

print(a+b)
# Out:
# 16

# %%
year = "2019"
month = '04'
day ='26'
hour = '11'
minute = '34'
second = '27'

print(year, month, day, sep='/', end=' ')
print(hour, minute, second,sep=':',end='')
# Out:
# 2019/04/26 11:34:27

# %%
i = 0
while i in range(1,10,2):
  i += 1
  if il > 10: break

print('*' * i)

# %%
int1 = int(input("숫자를 넣어주세요: "))

for i in range(1,int1*2,2):
  print((" " * ( (int1 * 2  - 1 -i) // 2))+ ('*' * i))
# Out:
# 숫자를 넣어주세요: 7
#       *
#      ***
#     *****
#    *******
#   *********
#  ***********
# *************

# %%
    line = int(input("Tree 의 높이를 입력하세요(5~30) : "))

    for x in range(1, line * 2, 2):
        print((" " * ( (line * 2 - 1 - x) // 2 )) + ("*" * x))

    for y in range(1, 4):
        print(" " * (line-2) + "***")
# Out:
# Tree 의 높이를 입력하세요(5~30) : 5
#     *
#    ***
#   *****
#  *******
# *********
#    ***
#    ***
#    ***

# %%
i = 0
while True:
  i += 1
  if i > 5: break
  print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
# 문제 11
s = 0

for i in range(1,101):
  s += i
  i += 1

print(s)
# Out:
# 5050

# %%
#문제 12
class Wizard:
  def __init__(self, health, mana, armor):
    self.health = health
    self.mana = mana
    self.armor = armor
  def attack(self):
    print("파이어볼")

x = Wizard(health = 545, mana = 210, armor = 10)
print(x.health, x.mana, x.armor)
x.attack()
# Out:
# 545 210 10
# 파이어볼

# %%
#문제 13
# n = int(input("몇번째 행성입니까? "))
# a = {"수성":1, "금성":2, "지구":3, "화성":4, "목성":5, "토성":6, "천왕성":7, "해왕성":8}
# if n == a:

# print(a)

a = ["수성","금성","지구","화성","목성","토성","천왕성","해왕성"] 
n = int(input("행성의 이름이 어떻게 되나요? "))

print(a)
# Out:
# 행성의 이름이 어떻게 되나요? 1
# ['수성', '금성', '지구', '화성', '목성', '토성', '천왕성', '해왕성']

# %%
#문제 14
int1 = int(input("숫자를 입력 해주세요: "))
if int1 % 3 == 0 :
  print("짝")
else:
  print(int1)
# Out:
# 숫자를 입력 해주세요: 4
# 4

# %%
#문제 15
x = input("이름을 입력해 주세요: ")
print("안녕하세요 저는", x, "입니다")
# Out:
# 이름을 입력해 주세요: 김승주
# 안녕하세요 저는 김승주 입니다

# %%
#문제 16
# n = list(input("거꾸로 말해요: "))
# n.reverse()
# n
s=input('')
print(s[::-1])
# Out:
# 거꾸로
# 로꾸거

# %%
#문제 17
x = int(input("키를 입력해 주세요: "))
if x > 150:
  print("yes")
else:
  print("no")
# Out:
# 키를 입력해 주세요: 151
# yes

# %%
#문제 18
# int1 = int(input("점수를 입력해 주세요: "))
# int2 = int(input("점수를 입력해 주세요: "))
# int3 = int(input("점수를 입력해 주세요: "))


# n = [int(x) for x in input("점수를 입력해 주세요: ").split()]
# print(sum(n) // len(n))

n = list(map(int,input().split()))
print(int(sum(n)) // len(n))
# Out:
# 20 30 40 50 60
# 40

# %%
#문제 19
# int1 = int(input("숫자를 입력해 주세요: "))
# int2 = int(input("숫자를 입력해 주세요: "))

# pow = (int1 ** int2)
# print(pow)

n = list(map(int,input().split()))
print(n[0] ** n[1])
# Out:
# 2 3
# 8

# %%
#문제 20
n = list(map(int,input().split()))
print(n[0]//n[1], n[0] % n[1])
# Out:
# 3 5
# 0 3

# %%
## 문제 21 set 이 아닌 것은
# 2번 dict 이다.

x = {1,2,3,4,5,6,7}
x = {}
x = set('python')
x = set(range(5))
x = set()

# %%
n = input("영어 소문자 입력 하세요: ")
n.upper()
# Out:
# 영어 소문자 입력 하세요: isdf
# 'ISDF'

# %%
#문제 25
def circle(n):
  return n * n * 3.14

circle(int(input("반지름 길이: ")))
# Out:
# 반지름 길이: 7
# 153.86

# %%
p = {
    '수성':'Mercury', 
     '금성':'Venus', 
     '지구':'Earth', 
     '화성':'Mars', 
     '목성':'Jupiter', 
     '토성':'Saturn', 
     '천왕성':'Uranus', 
     '해왕성':'Neptune' 
}
try:
  a=input()
  print(p[a])
except KeyError:
  print('찾는 행성이 없습니다.')
# Out:
# 지구
# Earth
